# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Submited version.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("Submited version.csv")
#
# File /opt/miniconda3/envs/torch/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df
# Out:
#      Economies  Year   ID  Institutions  Human capital and research  \
# 0      Albania  2011    2          65.2                        32.7
# 1      Albania  2012    2          55.0                        26.2
# 2      Albania  2013    2          58.9                        27.1
# 3      Albania  2014    2          58.8                        22.8
# 4      Albania  2015    2          60.1                        21.8
# ...        ...   ...  ...           ...                         ...
# 1783  Zimbabwe  2018  230          36.4                        27.0
# 1784  Zimbabwe  2019  230          37.6                        27.8
# 1785  Zimbabwe  2020  230          40.3                        20.9
# 1786  Zimbabwe  2021  230          40.7                        24.6
# 1787  Zimbabwe  2022  230          33.3                        21.6
#
#       Infrastructure  Market sophistication  Business sophistication  \
# 0               26.4                   47.5                     19.6
# ...

# %%
df[df.isna().sum(axis = 1) != 0]
# Out:
#      Economies  Year   ID  Institutions  Human capital and research  \
# 11     Albania  2022    2          51.4                        22.7
# 23     Algeria  2022    3          47.2                        26.1
# 24      Angola  2011    6           NaN                         NaN
# 29      Angola  2016    6           NaN                         NaN
# 30      Angola  2017    6           NaN                         NaN
# ...        ...   ...  ...           ...                         ...
# 1762     Yemen  2021  228          27.6                        10.1
# 1763     Yemen  2022  228          17.5                        11.3
# 1775    Zambia  2022  229          37.5                        14.8
# 1781  Zimbabwe  2016  230           NaN                         NaN
# 1787  Zimbabwe  2022  230          33.3                        21.6
#
#       Infrastructure  Market sophistication  Business sophistication  \
# 11              46.3                   25.4                     30.4
# ...

# %%
df_clean = df.dropna()

# %%
df_clean
# Out:
#      Economies  Year   ID  Institutions  Human capital and research  \
# 0      Albania  2011    2          65.2                        32.7
# 1      Albania  2012    2          55.0                        26.2
# 2      Albania  2013    2          58.9                        27.1
# 3      Albania  2014    2          58.8                        22.8
# 4      Albania  2015    2          60.1                        21.8
# ...        ...   ...  ...           ...                         ...
# 1782  Zimbabwe  2017  230          35.7                        28.7
# 1783  Zimbabwe  2018  230          36.4                        27.0
# 1784  Zimbabwe  2019  230          37.6                        27.8
# 1785  Zimbabwe  2020  230          40.3                        20.9
# 1786  Zimbabwe  2021  230          40.7                        24.6
#
#       Infrastructure  Market sophistication  Business sophistication  \
# 0               26.4                   47.5                     19.6
# ...

# %%
df_clean.to_csv("cleaned_data.csv", index = False)

# %%
df_clean = pd.read_csv('/Users/kylexiao/Desktop/MIE1624H/final project/cleaned_data.csv')

# %%
df_clean = df_clean.drop(columns=['Economies','Year','ID'])

# %%
target = df_clean['Global Innovation Index']
df_clean = df_clean.drop(columns=['Global Innovation Index'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_clean, target, test_size=0.2, random_state=42)

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.4f}")

# Get feature importance (coefficients)
feature_importance = pd.DataFrame({
    'Feature': df_clean.columns,
    'Coefficient': model.coef_
}).sort_values(by='Coefficient', ascending=False)

print("Feature Importance:")
print(feature_importance)
# Out:
# Mean Squared Error: 0.0011
# Feature Importance:
#                                               Feature   Coefficient
# 5                    Knowledge and technology outputs  2.501038e-01
# 6                                    Creative outputs  2.497186e-01
# 4                             Business sophistication  1.001427e-01
# 0                                        Institutions  9.991839e-02
# 3                               Market sophistication  9.983966e-02
# 1                          Human capital and research  9.980279e-02
# 2                                      Infrastructure  9.954935e-02
# 9   GDP per capita, ppp (constant 2017 internation...  1.377560e-06
# 7             GNI per capita in current U.S. dollars   7.070466e-07
# 10       GDP per capita ppp (current international $) -1.414954e-06
# 8                       Income level (GNI Thresholds) -1.036347e-03
